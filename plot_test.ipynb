# %%
import pandas as pd
data = pd.read_csv('combined_data.csv',encoding='latin1')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    imdb_id    profit  \
# 0           0             2  tt0024034   1842000
# 1           1             4  tt0031679   8100000
# 2           2            10  tt0037008    980000
# 3           3            16  tt0044081   6200000
# 4           4            17  tt0043949  21750000
#
#                                               Actors  \
# 0  Warner Baxter, Bebe Daniels, George Brent, Rub...
# 1  Jean Arthur, James Stewart, Claude Rains, Edwa...
# 2  Gene Tierney, Dana Andrews, Clifton Webb, Vinc...
# 3  Vivien Leigh, Marlon Brando, Kim Hunter, Karl ...
# 4  Robert Taylor, Deborah Kerr, Leo Genn, Peter U...
#
#                      Director                      Genre  IMDB Rating  \
# 0                 Lloyd Bacon   Comedy, Musical, Romance          7.6
# 1                 Frank Capra              Comedy, Drama          8.2
# 2              Otto Preminger  Drama, Film-Noir, Mystery          8.1
# ...

# %%
producer = data['Production']

# %%
producer_list = producer.value_counts()
producer_list_dict = dict(producer_list)

# %%
a = sorted(producer_list.items(), key=lambda d:d[1], reverse = True)

# %%
# %matplotlib inline
producer_list.plot.bar()

# %%
round(12.334,2)
# Out:
# 12.33
